# %% [markdown]
# # UQFF Assimilation Tutorial: SM — Standard Model Free Parameters
#
# **24 observables** in this domain. Each one is dispatchable through the
# public calculator API. This notebook walks through the dispatch mechanism and
# shows worked examples for representative observables.
#
# **Source of truth:** `assimilation_dispatch.py` (full 116-observable catalog).
# **Public API:** `import uqff_pure_calculator as u`.
# **Reference:** `ASSIMILATION_GEOMETRY_ATLAS.md` (per-observable provenance)
# and `OVERDETERMINATION_MAP.md` (multi-path corroboration table).

# %% [markdown]
# ## Setup
#
# Import the calculator and the dispatch catalog.

# %%
import uqff_pure_calculator as u
import assimilation_dispatch as ad

# All observables in domain 'SM':
obs_in_domain = sorted(n for n, r in ad.DISPATCH.items()
                      if r['domain'] == 'SM')
print(f'Domain has {len(obs_in_domain)} observables:')
for n in obs_in_domain:
    rec = ad.DISPATCH[n]
    print(f'  {n:42s}  owner={rec["owner_geometry"]:10s}  resid={rec["residual_pct"]}%')

# %% [markdown]
# ## Deep-dive: representative observables
#
# For each, we show:
# 1. **Simple call** — returns `{'value': X}` matching the existing 42-surface contract.
# 2. **Decomposed call** — adds `decompose=True` to get the 8-field provenance dict
#    (value, target, residual_pct, geometry_used, numeric_system, overdetermination_N, alternate_paths, assimilation_status).

# %% [markdown]
# ### `Clifford_qualia_states`
#
# - **Formula:** `8192 = 2^13 = SO(26) Clifford bundle qualia states`
# - **Owner geometry:** `d26`
# - **Documented residual:** 0.0%
# - **Primary source:** PAPER_1666

# %%
# Simple call — Rule 5 contract (returns {'value': X})
simple = u.calculate_analytic_closures(
    {'qcalcgeom_solve': {'observable': 'Clifford_qualia_states'}})
print('Simple:', simple)

# %%
# Decomposed — full 8-field provenance dict
decomp = u.calculate_analytic_closures(
    {'qcalcgeom_solve': {'observable': 'Clifford_qualia_states', 'decompose': True}})
for k, v in decomp['value'].items():
    if k != 'alternate_paths':
        print(f'  {k:24s} {v}')

# %% [markdown]
# ### `SM_PMNS_theta_12_deg`
#
# - **Formula:** `theta_12 = 3*SO_5 + D_PHYS - Phi_res + SSQ - F_TRZ - F_TRZ*K_MEX deg`
# - **Owner geometry:** `d26`
# - **Documented residual:** 1.0%
# - **Primary source:** PAPER_1209HH

# %%
# Simple call — Rule 5 contract (returns {'value': X})
simple = u.calculate_analytic_closures(
    {'qcalcgeom_solve': {'observable': 'SM_PMNS_theta_12_deg'}})
print('Simple:', simple)

# %%
# Decomposed — full 8-field provenance dict
decomp = u.calculate_analytic_closures(
    {'qcalcgeom_solve': {'observable': 'SM_PMNS_theta_12_deg', 'decompose': True}})
for k, v in decomp['value'].items():
    if k != 'alternate_paths':
        print(f'  {k:24s} {v}')

# %% [markdown]
# ### `SM_alpha_s_M_Z_S378`
#
# - **Formula:** `alpha_s(M_Z) = F_TRZ*K_MEX*SSQ - F_TRZ^3*Phi_res`
# - **Owner geometry:** `dpm`
# - **Documented residual:** 0.5%
# - **Primary source:** PAPER_1209HH

# %%
# Simple call — Rule 5 contract (returns {'value': X})
simple = u.calculate_analytic_closures(
    {'qcalcgeom_solve': {'observable': 'SM_alpha_s_M_Z_S378'}})
print('Simple:', simple)

# %%
# Decomposed — full 8-field provenance dict
decomp = u.calculate_analytic_closures(
    {'qcalcgeom_solve': {'observable': 'SM_alpha_s_M_Z_S378', 'decompose': True}})
for k, v in decomp['value'].items():
    if k != 'alternate_paths':
        print(f'  {k:24s} {v}')

# %% [markdown]
# ### `SM_cabibbo_sin_primary`
#
# - **Formula:** `sin(theta_C) = (N_CH * K_MEX * beta_i) / (A_5 * Phi_res) [primary, 5-primitive triadic ratio form]`
# - **Owner geometry:** `dpm`
# - **Documented residual:** 0.008%
# - **Primary source:** PAPER_1167

# %%
# Simple call — Rule 5 contract (returns {'value': X})
simple = u.calculate_analytic_closures(
    {'qcalcgeom_solve': {'observable': 'SM_cabibbo_sin_primary'}})
print('Simple:', simple)

# %%
# Decomposed — full 8-field provenance dict
decomp = u.calculate_analytic_closures(
    {'qcalcgeom_solve': {'observable': 'SM_cabibbo_sin_primary', 'decompose': True}})
for k, v in decomp['value'].items():
    if k != 'alternate_paths':
        print(f'  {k:24s} {v}')

# %% [markdown]
# ### `SM_cabibbo_sin_alternate`
#
# - **Formula:** `sin(theta_C) = (D_phys * K_MEX * S_26) / (D_BSFG * N_CH) [alternate, 5-primitive Ramanujan-amplification form]`
# - **Owner geometry:** `dpm`
# - **Documented residual:** 0.025%
# - **Primary source:** PAPER_1167

# %%
# Simple call — Rule 5 contract (returns {'value': X})
simple = u.calculate_analytic_closures(
    {'qcalcgeom_solve': {'observable': 'SM_cabibbo_sin_alternate'}})
print('Simple:', simple)

# %%
# Decomposed — full 8-field provenance dict
decomp = u.calculate_analytic_closures(
    {'qcalcgeom_solve': {'observable': 'SM_cabibbo_sin_alternate', 'decompose': True}})
for k, v in decomp['value'].items():
    if k != 'alternate_paths':
        print(f'  {k:24s} {v}')

# %% [markdown]
# ## Multi-path corroboration: `SM_cabibbo_sin_primary` + `SM_cabibbo_sin_alternate`
#
# Two structurally-independent UQFF closures for the same observable. Their
# agreement at varying precision (sharing only one or two primitives) is the
# framework's evidence framework — joint probability of two random combinations
# agreeing at <0.03% is below 10^-6. Documented in PAPER_1156 Appendix A (BAO)
# and Appendix B (Cabibbo, pending Lagrangian re-derivation per §A.6).

# %%
# Multi-path comparison
primary = u.calculate_analytic_closures(
    {'qcalcgeom_solve': {'observable': 'SM_cabibbo_sin_primary'}})['value']
alternate = u.calculate_analytic_closures(
    {'qcalcgeom_solve': {'observable': 'SM_cabibbo_sin_alternate'}})['value']
print(f'Primary path   = {primary}')
print(f'Alternate path = {alternate}')
print(f'Spread         = {abs(primary - alternate):.2e}')

# %% [markdown]
# ## Cross-references
#
# - **Per-observable provenance:** `ASSIMILATION_GEOMETRY_ATLAS.md` § SM
#   (24 entries with formula, owner, residual, source, session script).
# - **Full 4×3 dispatch matrix:** `OVERDETERMINATION_MAP.csv` (filter by domain 'SM').
# - **Discovery cheat sheet:** `CLOSURE_ATLAS.md` §12.
# - **CLI equivalent:** `uqff list --domain SM` and `uqff assimilate <observable> --decompose`.
# - **Audit trail:** `SESSION_LOG.md` — search for `SM` to find the rounds
#   in which this domain's dispatch entries were injected and verified.
