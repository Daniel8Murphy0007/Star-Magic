# %% [markdown]
# # UQFF Assimilation Tutorial: astro — Astrophysical Constants
#
# **14 observables** in this domain. Each one is dispatchable through the
# public calculator API. This notebook walks through the dispatch mechanism and
# shows worked examples for representative observables.
#
# **Source of truth:** `assimilation_dispatch.py` (full 116-observable catalog).
# **Public API:** `import uqff_pure_calculator as u`.
# **Reference:** `ASSIMILATION_GEOMETRY_ATLAS.md` (per-observable provenance)
# and `OVERDETERMINATION_MAP.md` (multi-path corroboration table).

# %% [markdown]
# ## Setup
#
# Import the calculator and the dispatch catalog.

# %%
import uqff_pure_calculator as u
import assimilation_dispatch as ad

# All observables in domain 'astro':
obs_in_domain = sorted(n for n, r in ad.DISPATCH.items()
                      if r['domain'] == 'astro')
print(f'Domain has {len(obs_in_domain)} observables:')
for n in obs_in_domain:
    rec = ad.DISPATCH[n]
    print(f'  {n:42s}  owner={rec["owner_geometry"]:10s}  resid={rec["residual_pct"]}%')

# %% [markdown]
# ## Deep-dive: representative observables
#
# For each, we show:
# 1. **Simple call** — returns `{'value': X}` matching the existing 42-surface contract.
# 2. **Decomposed call** — adds `decompose=True` to get the 8-field provenance dict
#    (value, target, residual_pct, geometry_used, numeric_system, overdetermination_N, alternate_paths, assimilation_status).

# %% [markdown]
# ### `BH_seed_mass`
#
# - **Formula:** `M_seed = A_5 * D_BSFG^2 * D_crit = 60 * 36 * 26 = 56,160 M_Sun`
# - **Owner geometry:** `d26`
# - **Documented residual:** 0.0%
# - **Primary source:** PAPER_1650

# %%
# Simple call — Rule 5 contract (returns {'value': X})
simple = u.calculate_analytic_closures(
    {'qcalcgeom_solve': {'observable': 'BH_seed_mass'}})
print('Simple:', simple)

# %%
# Decomposed — full 8-field provenance dict
decomp = u.calculate_analytic_closures(
    {'qcalcgeom_solve': {'observable': 'BH_seed_mass', 'decompose': True}})
for k, v in decomp['value'].items():
    if k != 'alternate_paths':
        print(f'  {k:24s} {v}')

# %% [markdown]
# ### `GW_memory_fraction`
#
# - **Formula:** `h_mem/h_peak = F_TRZ * beta_i = 0.1 * 0.6029`
# - **Owner geometry:** `qcalcgeom`
# - **Documented residual:** 0.0%
# - **Primary source:** PAPER_1766

# %%
# Simple call — Rule 5 contract (returns {'value': X})
simple = u.calculate_analytic_closures(
    {'qcalcgeom_solve': {'observable': 'GW_memory_fraction'}})
print('Simple:', simple)

# %%
# Decomposed — full 8-field provenance dict
decomp = u.calculate_analytic_closures(
    {'qcalcgeom_solve': {'observable': 'GW_memory_fraction', 'decompose': True}})
for k, v in decomp['value'].items():
    if k != 'alternate_paths':
        print(f'  {k:24s} {v}')

# %% [markdown]
# ### `Pop_III_IMF_max`
#
# - **Formula:** `M_max = A_5 * 2 = 120 M_Sun`
# - **Owner geometry:** `dpm`
# - **Documented residual:** 0.0%
# - **Primary source:** PAPER_1652

# %%
# Simple call — Rule 5 contract (returns {'value': X})
simple = u.calculate_analytic_closures(
    {'qcalcgeom_solve': {'observable': 'Pop_III_IMF_max'}})
print('Simple:', simple)

# %%
# Decomposed — full 8-field provenance dict
decomp = u.calculate_analytic_closures(
    {'qcalcgeom_solve': {'observable': 'Pop_III_IMF_max', 'decompose': True}})
for k, v in decomp['value'].items():
    if k != 'alternate_paths':
        print(f'  {k:24s} {v}')

# %% [markdown]
# ## Cross-references
#
# - **Per-observable provenance:** `ASSIMILATION_GEOMETRY_ATLAS.md` § astro
#   (14 entries with formula, owner, residual, source, session script).
# - **Full 4×3 dispatch matrix:** `OVERDETERMINATION_MAP.csv` (filter by domain 'astro').
# - **Discovery cheat sheet:** `CLOSURE_ATLAS.md` §12.
# - **CLI equivalent:** `uqff list --domain astro` and `uqff assimilate <observable> --decompose`.
# - **Audit trail:** `SESSION_LOG.md` — search for `astro` to find the rounds
#   in which this domain's dispatch entries were injected and verified.
